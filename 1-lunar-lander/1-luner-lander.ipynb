# %%
# !apt install swig cmake

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# %%
# !apt-get update
# !apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-0.04776433  0.37539226 -0.66619956 -3.4528992   2.72239     2.4114401
#   0.50794303  0.7482365 ]
#
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
env_id = 'LunarLander-v2'
env = make_vec_env(env_id, n_envs=16)

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 128,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1
)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=1_000_000)
model_name = "1-lunar-lander"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91       |
# |    ep_rew_mean     | -178     |
# | time/              |          |
# |    fps             | 1608     |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.5         |
# |    ep_rew_mean          | -172         |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 2            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0047857948 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000596     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 5.79e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.3        |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004817183 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00511    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+03    |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 3.69e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.4       |
# |    ep_rew_mean          | -117       |
# | time/                   |            |
# |    fps                  | 988        |
# |    iterations           | 4          |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00965225 |
# |    clip_fraction        | 0.0401     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.00835   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 933        |
# |    n_updates            | 12         |
# |    policy_gradient_loss | -0.0062    |
# |    value_loss           | 2.16e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 5           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009790322 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0225     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 550         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 1.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 6           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011299327 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.00289    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 1.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | -82.5       |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 7           |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009495537 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.00131    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 585         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00505    |
# |    value_loss           | 748         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | -65.5        |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 8            |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0072071357 |
# |    clip_fraction        | 0.0993       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -2.07e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 311          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 491          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -58.1       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 9           |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.010451859 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.00109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 236         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00642    |
# |    value_loss           | 519         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | -31          |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 10           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0074344203 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -1.34e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 263          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 441          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | -22.3       |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 11          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.006887872 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -7.39e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 246         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 469         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | -25.1       |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 12          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005850505 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -6.6e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 272         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.000931   |
# |    value_loss           | 561         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 13          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.007855025 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 9.18e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 262         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 514         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 274          |
# |    ep_rew_mean          | -4.64        |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 14           |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0014045306 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.000537     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 271          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.000681    |
# |    value_loss           | 462          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | -0.904       |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 15           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0027514598 |
# |    clip_fraction        | 0.00287      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 345          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 1.28         |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 16           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0030422364 |
# |    clip_fraction        | 0.00584      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 282          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 401          |
# |    ep_rew_mean          | -1.69        |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 17           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0043816837 |
# |    clip_fraction        | 0.00497      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.665        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 135          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 238          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 442          |
# |    ep_rew_mean          | -4.06        |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 18           |
# |    time_elapsed         | 414          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0033957688 |
# |    clip_fraction        | 0.00668      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.628        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.4         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 252          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 527          |
# |    ep_rew_mean          | -1.38        |
# | time/                   |              |
# |    fps                  | 692          |
# |    iterations           | 19           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0043690107 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 262          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 522          |
# |    ep_rew_mean          | 7.07         |
# | time/                   |              |
# |    fps                  | 680          |
# |    iterations           | 20           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0065297484 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 86           |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 201          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 490          |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 21           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0028175623 |
# |    clip_fraction        | 0.000824     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000368    |
# |    value_loss           | 206          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 687         |
# |    iterations           | 22          |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005529285 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.2        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 169         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 530          |
# |    ep_rew_mean          | 32.7         |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 23           |
# |    time_elapsed         | 548          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0057832683 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 127          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 595         |
# |    ep_rew_mean          | 38.8        |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 24          |
# |    time_elapsed         | 583         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.006895696 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.3        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | 45          |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 25          |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.005924183 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.6        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 90.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 702          |
# |    ep_rew_mean          | 51.6         |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 26           |
# |    time_elapsed         | 655          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0033995346 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 736          |
# |    ep_rew_mean          | 58.3         |
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 27           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0061205113 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.3         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 65.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 71.3         |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 28           |
# |    time_elapsed         | 732          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0058645504 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.8         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 63.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 819          |
# |    ep_rew_mean          | 78.7         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 29           |
# |    time_elapsed         | 770          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0031110197 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.6         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 104          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 847          |
# |    ep_rew_mean          | 87.1         |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 30           |
# |    time_elapsed         | 802          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0031806638 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.5         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 62.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | 87.8        |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 31          |
# |    time_elapsed         | 834         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.006158317 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 98.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 849          |
# |    ep_rew_mean          | 94.9         |
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 32           |
# |    time_elapsed         | 869          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0070610372 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29           |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 57           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 860         |
# |    ep_rew_mean          | 97.8        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 33          |
# |    time_elapsed         | 903         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.008514648 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.7        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 63.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 34          |
# |    time_elapsed         | 936         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.003488053 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.000508   |
# |    value_loss           | 41.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 885         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 35          |
# |    time_elapsed         | 973         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.004527686 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.4        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 55.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 36           |
# |    time_elapsed         | 1007         |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0038825157 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000359     |
# |    value_loss           | 18.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 920          |
# |    ep_rew_mean          | 114          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 37           |
# |    time_elapsed         | 1045         |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0038740071 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.01         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000881    |
# |    value_loss           | 40.5         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 922       |
# |    ep_rew_mean          | 115       |
# | time/                   |           |
# |    fps                  | 576       |
# |    iterations           | 38        |
# |    time_elapsed         | 1080      |
# |    total_timesteps      | 622592    |
# | train/                  |           |
# |    approx_kl            | 0.0053068 |
# |    clip_fraction        | 0.02      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.977     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 15.8      |
# |    n_updates            | 148       |
# |    policy_gradient_loss | -0.000409 |
# |    value_loss           | 25.6      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 927         |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 39          |
# |    time_elapsed         | 1113        |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.004960603 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.000983   |
# |    value_loss           | 47.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 934         |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 40          |
# |    time_elapsed         | 1150        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.003328524 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000535   |
# |    value_loss           | 96.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 41          |
# |    time_elapsed         | 1185        |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.011374537 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.55        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 14.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 42           |
# |    time_elapsed         | 1220         |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0036338605 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.69         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 34.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 893          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 43           |
# |    time_elapsed         | 1256         |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0015358792 |
# |    clip_fraction        | 0.00339      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -5.04e-05    |
# |    value_loss           | 58           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 911         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 44          |
# |    time_elapsed         | 1292        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.004444199 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.000883   |
# |    value_loss           | 64.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 917          |
# |    ep_rew_mean          | 120          |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 45           |
# |    time_elapsed         | 1328         |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0035134326 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.89         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000792    |
# |    value_loss           | 22.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 911        |
# |    ep_rew_mean          | 121        |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 46         |
# |    time_elapsed         | 1362       |
# |    total_timesteps      | 753664     |
# | train/                  |            |
# |    approx_kl            | 0.00417992 |
# |    clip_fraction        | 0.0297     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.999     |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.68       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.000506  |
# |    value_loss           | 29.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 47          |
# |    time_elapsed         | 1396        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.004210068 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000489   |
# |    value_loss           | 29.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 549          |
# |    iterations           | 48           |
# |    time_elapsed         | 1431         |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0047136564 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.25         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | 0.00012      |
# |    value_loss           | 20.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 49          |
# |    time_elapsed         | 1468        |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.006488543 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.3        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 34.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 952          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 50           |
# |    time_elapsed         | 1499         |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0056962273 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.91         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000743    |
# |    value_loss           | 38.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 952         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 51          |
# |    time_elapsed         | 1535        |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.004239776 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.19        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 958         |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 52          |
# |    time_elapsed         | 1572        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004644988 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.97        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.000877   |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 972          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 53           |
# |    time_elapsed         | 1605         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0028504804 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.12         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000275    |
# |    value_loss           | 10.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 979          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 54           |
# |    time_elapsed         | 1641         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0043157917 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.12         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 5.81e-05     |
# |    value_loss           | 8.07         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 55           |
# |    time_elapsed         | 1676         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0036867654 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.5          |
# |    n_updates            | 216          |
# |    policy_gradient_loss | 0.000249     |
# |    value_loss           | 7.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 56           |
# |    time_elapsed         | 1703         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0044857203 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.956       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.04         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000523    |
# |    value_loss           | 7.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 57           |
# |    time_elapsed         | 1726         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0035958877 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.952       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.93         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000442    |
# |    value_loss           | 8.76         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 58          |
# |    time_elapsed         | 1752        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.004714572 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36        |
# |    n_updates            | 228         |
# |    policy_gradient_loss | 0.000397    |
# |    value_loss           | 4.86        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 59           |
# |    time_elapsed         | 1777         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0070535755 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 4.62         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 60          |
# |    time_elapsed         | 1803        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.002104266 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 236         |
# |    policy_gradient_loss | -4.85e-05   |
# |    value_loss           | 19.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 61          |
# |    time_elapsed         | 1828        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.003772148 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000769   |
# |    value_loss           | 17.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 62           |
# |    time_elapsed         | 1853         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0047433665 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51         |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.00075     |
# |    value_loss           | 5.36         |
# ------------------------------------------

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=250.25 +/- 20.26048002277981

# %%
import os
from pathlib import Path
import tempfile

import numpy as np
from stable_baselines3.common.vec_env import (
    DummyVecEnv,
    VecVideoRecorder
)


def generate_replay(
    model,
    eval_env,
    video_length: int = 1000,
    is_deterministic: bool = True,
    local_path: Path = './',
    file_name = 'replay.mp4'
):
    """
    Generate a replay video of the agent
    :param model: trained model
    :param eval_env: environment used to evaluate the agent
    :param video_length: length of the video (in timesteps)
    :param is_deterministic: use deterministic or stochastic actions
    :param local_path: path of the local repository
    """
    # This is another temporary directory for video outputs
    # SB3 created a -step-0-to-... meta files as well as other
    # artifacts which we don't want in the repo.
    with tempfile.TemporaryDirectory() as tmpdirname:
        # Step 1: Create the VecVideoRecorder
        env = VecVideoRecorder(
            eval_env,
            tmpdirname,
            record_video_trigger=lambda x: x == 0,
            video_length=video_length,
            name_prefix="",
        )

        obs = env.reset()
        lstm_states = None
        episode_starts = np.ones((env.num_envs,), dtype=bool)

        try:
            for _ in range(video_length):
                action, lstm_states = model.predict(
                    obs,
                    state=lstm_states,
                    episode_start=episode_starts,
                    deterministic=is_deterministic,
                )
                obs, _, episode_starts, _ = env.step(action)

            # Save the video
            env.close()

            # Convert the video with x264 codec
            inp = env.video_recorder.path
            out = os.path.join(local_path, file_name)
            os.system(f"ffmpeg -y -i {inp} -vcodec h264 {out}".format(inp, out))

        except KeyboardInterrupt:
            pass
        except Exception as e:
            print(str(e))

# %%
replay_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
generate_replay(
    model,
    replay_env,
    file_name=model_name+'.mp4'
)
# Out:
# Saving video to /tmp/tmpguegdmm0/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpguegdmm0/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpguegdmm0/-step-0-to-step-1000.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpguegdmm0/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:20.02, start: 0.000000, bitrate: 83 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 600x400, 78 kb/s, 50 fps, 50 tbr, 12800 tbn, 100 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5575ed6bfb80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5575ed6bfb80] profile High, level 3.1
# [libx264 @ 0x5575ed6bfb80] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './1-lunar-lander.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 600x400, q=-1--1, 50 fps, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpguegdmm0/-step-0-to-step-1000.mp4
# frame= 1001 fps=750 q=-1.0 Lsize=     196kB time=00:00:19.96 bitrate=  80.4kbits/s speed=14.9x
# video:183kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.765255%
# [libx264 @ 0x5575ed6bfb80] frame I:5     Avg QP:11.84  size:  1886
# [libx264 @ 0x5575ed6bfb80] frame P:262   Avg QP:23.42  size:   244
# [libx264 @ 0x5575ed6bfb80] frame B:734   Avg QP:26.08  size:   155
# [libx264 @ 0x5575ed6bfb80] consecutive B-frames:  1.3%  1.2%  4.8% 92.7%
# [libx264 @ 0x5575ed6bfb80] mb I  I16..4: 76.9% 16.8%  6.3%
# [libx264 @ 0x5575ed6bfb80] mb P  I16..4:  0.3%  0.5%  0.2%  P16..4:  2.0%  0.5%  0.2%  0.0%  0.0%    skip:96.4%
# [libx264 @ 0x5575ed6bfb80] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8:  3.4%  0.3%  0.0%  direct: 0.1%  skip:96.0%  L0:54.5% L1:44.6% BI: 0.8%
# [libx264 @ 0x5575ed6bfb80] 8x8 transform intra:28.3% inter:17.0%
# [libx264 @ 0x5575ed6bfb80] coded y,uvDC,uvAC intra: 8.3% 13.6% 12.5% inter: 0.2% 0.4% 0.3%
# [libx264 @ 0x5575ed6bfb80] i16 v,h,dc,p: 83% 12%  5%  0%
# [libx264 @ 0x5575ed6bfb80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 17% 74%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x5575ed6bfb80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 14% 63%  2%  3%  1%  3%  1%  2%
# [libx264 @ 0x5575ed6bfb80] i8c dc,h,v,p: 91%  6%  3%  0%
# [libx264 @ 0x5575ed6bfb80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5575ed6bfb80] ref P L0: 62.4%  1.7% 24.4% 11.5%
# [libx264 @ 0x5575ed6bfb80] ref B L0: 68.2% 27.9%  4.0%
# [libx264 @ 0x5575ed6bfb80] ref B L1: 92.8%  7.2%
# [libx264 @ 0x5575ed6bfb80] kb/s:74.76

# %%
# %%html
# <video controls autoplay><source src="./1-lunar-lander.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="./1-lunar-lander.mp4" type="video/mp4"></video>
